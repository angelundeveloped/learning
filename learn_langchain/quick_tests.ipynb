# %%
# LangSmith Studio
from langchain.agents import create_agent

def send_email(to: str, subject, body: str) -> str:
    """Send an email to a recipient"""
    email  = {
        "to": to,
        "subject": subject,
        "body":"body"
    }

    # ... email sending logic
    return f"Email sent to {to}"


def say_hi(name: str) -> str:
    """Say hi to the user"""
    return  f"Hi {name}"

email_agent_openai = create_agent(
    model="",
    tools=[send_email, say_hi],
    system_prompt="You are an assistant. Use the tools available to you when appropriate."
)

email_agent_gemini = create_agent(
    model="gemini-flash-lite-latest",
    tools=[send_email, say_hi],
    system_prompt="You are an assistant. Use the tools available to you when appropriate."
)
